# %% [markdown]
# <a href="https://colab.research.google.com/github/veillette/jupyterNotebooks/blob/main/Optics/HWOpticalInstruments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework on Optical Instruments

# %% [markdown]
# 1)	A labor student working for the marketing department wishes to photograph the spires of Draper building. The height of Draper is 43-m according to (https://en.wikipedia.org/wiki/List_of_tallest_buildings_in_Kentucky). If the labor student sets her photographic equipment in the middle of the quad, 75 meters away from the building, what focal-length lens should be used if the image is to fill the 36-mm height of the CCD?

# %% [markdown]
# 2)	In visual perception, the far point is the point at which an object must be placed along the optical axis of the eye for its image to be focused on the retina when the eye is not accommodating. For a normal eye, the near point is located 25 cm from the eye. Consider a person who has a far point of 16 cm. What is the diopter (or power) of the glasses that would correct this vision if the glasses were placed 2.0 cm from the eye? Now consider that this person prefers to wear contact lenses, what power contact lenses, placed on the eye, would the person need?

# %% [markdown]
# 3)	 A biologist examines a stag beetle with a 15.0 cm focal length magnifying glass held 13.5 cm from the beetle.
#
#   ![stagBeetle.jpg](data:image/jpeg;base64,...)
#
# - (a) Where is the image (with respect to the location of the lens) ?
# - (b) What is its magnification of the image?
# - (c) How big is the image of the 0.10cm-long antler of the beetle?

# %% [markdown]
# 4)	Dermacentor variabilis, also known as the American dog tick or Wood tick, is one of the most well-known hard ticks. It is relatively small, about 3.3 mm in size and can be found in shrubby and long grass areas. It can be readily found in Kentucky. Consider that you catch such a tick and view it with a 9.50-cm-focal-length lens. Your normal eye views the image at its near point.
#
# ![Dermacetor.jpg](data:image/jpeg;base64,...)
#
#  Calculate
# - (a) the angular magnification,
# - (b) the width of the image, and
# - (c) the object distance from the lens.

# %% [markdown]
# 5) The most common type of microscope is the optical microscope. This is an optical instrument containing two or more lenses producing an enlarged image of a sample placed in the focal plane. Optical microscopes have refractive glass and occasionally of plastic or quartz, to focus light into the eye or nowadays, another camera. Microscope with eyepiece and objective lenses mounted on a turret are quite common in biology. Consider an eyepiece a magnification of 12.0, (often marked as ×12) combined with an objective lens with a magnification of 59. The eyepiece and objective are 20.0 cm apart.
# Determine
# - (a) the total magnification,
# - (b) the focal length of each lens, and
# - (c) where the object must be for a normal relaxed eye to see it in focus.

# %% [markdown]
# 6)	A bifocal lens is created with two different areas of vision correction, which are divided by a distinct line that sits horizontally across the lens. The top portion of the lens is used for distance, while the bottom portion of the lens is used for closer vision. Typically, optometrist design bifocals such that an individual can see distant objects clearly (upper part) and be able to read a book 25 cm away (lower part). Consider a patient who is only able to see objects that are between 45 cm and 155 cm away.  Assume that the glasses will be 2.0 cm from the eye. Find the power of lens of the bifocal that the optometrist would recommend. Note: you need to find the diopter for the upper and lower part of the bifocal lens.
#
# ![bifocalLenses.jpg](data:image/jpeg;base64,...)
